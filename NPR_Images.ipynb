# %%
import sys
#!{sys.executable} -m pip install requests
import requests

res = requests.get("https://www.npr.org")
print(res.text)
# Out:
# <!doctype html><html class="no-js" lang="en"><head><script>
#    try {var _sf_startpt=(new Date()).getTime();} catch(e){}
# </script>
# <meta itemscope itemtype="https://schema.org/SpeakableSpecification" itemref="speakable" /><title>NPR : National Public Radio : News &amp; Analysis, World, US, Music &amp; Arts : NPR</title><meta id="speakable" itemprop="cssSelector" content="[data-is-speakable]" /><meta id="google-site-verification" name="google-site-verification" content="1VqzbDm4ukeFVHOoq5LjIKA2fVKZD-EYv8cXZhKXSfU" /><meta charset="utf-8" /><meta name="robots" content="noarchive,index,follow" /><meta name="Rating" content="General" /><meta name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=no" /><meta name="npr-pjax" /><meta name="date" content="2020-08-01" /><link rel="canonical" href="https://www.npr.org/" /><meta name="description" content="NPR delivers breaking national and world news. Also top stories from business, politics, health, science, technology, music, arts and culture. Subscribe to podcasts and RSS feeds." /><link rel="alternate" type="application/rss+xml" title="Home Page Top Stories" href="https://feeds.npr.org/1002/rss.xml" /><link rel="alternate" type="application/rss+xml" title="NPR News" href="https://feeds.npr.org/1001/rss.xml" /><link rel="alternate" type="application/rss+xml" title="NPR Music" href="https://feeds.npr.org/1039/rss.xml" /><link rel="alternate" type="application/rss+xml" title="NPR Books" href="https://feeds.npr.org/1032/rss.xml" /><link rel="alternate" type="application/rss+xml" title="Morning Edition" href="https://feeds.npr.org/3/rss.xml" /><link rel="alternate" type="application/rss+xml" title="All Things Considered" href="https://feeds.npr.org/2/rss.xml" /><link rel="alternate" type="application/rss+xml" title="Wait Wait... Don't Tell Me!" href="https://feeds.npr.org/35/rss.xml" /><link rel="alternate" type="application/json" title="Home Page Top Stories" href="https://feeds.npr.org/feeds/1002/feed.json" /><link rel="alternate" type="application/json" title="NPR News" href="https://feeds.npr.org/feeds/1001/feed.json" /><link rel="alternate" type="application/json" title="NPR Music" href="https://feeds.npr.org/feeds/1039/feed.json" /><link rel="alternate" type="application/json" title="NPR Books" href="https://feeds.npr.org/feeds/1032/feed.json" /><link rel="alternate" type="application/json" title="Morning Edition" href="https://feeds.npr.org/feeds/3/feed.json" /><link rel="alternate" type="application/json" title="All Things Considered" href="https://feeds.npr.org/feeds/2/feed.json" /><link rel="alternate" type="application/json" title="Wait Wait... Don't Tell Me!" href="https://feeds.npr.org/feeds/35/feed.json" /><link rel="apple-touch-icon" sizes="180x180" href="https://static-assets.npr.org/static/images/favicon/favicon-180x180.png" /><link rel="icon" sizes="96x96" href="https://static-assets.npr.org/static/images/favicon/favicon-96x96.png" /><link rel="icon" sizes="32x32" href="https://static-assets.npr.org/static/images/favicon/favicon-32x32.png" /><link rel="icon" sizes="16x16" href="https://static-assets.npr.org/static/images/favicon/favicon-16x16.png" /><meta property="og:title" content="Home Page Top Stories" /><meta property="og:url" content="https://www.npr.org/" /><meta property="og:type" content="article" /><meta property="og:description" content="NPR delivers breaking national and world news. Also top stories from business, politics, health, science, technology, music, arts and culture. Subscribe to podcasts and RSS feeds." /><meta property="og:image" content="https://media.npr.org/include/images/facebook-default-wide.jpg?s=1400" /><meta property="og:site_name" content="NPR.org" /><meta property="fb:app_id" content="138837436154588" /><meta property="fb:pages" content="10643211755" /><meta property="article:content_tier" content="free" /><meta property="article:opinion" content="false" /><meta name="twitter:card" content="summary_large_image" /><meta name="twitter:title" content="Home Page Top Stories" /><meta name="twitter:site" content="@NPR" /><meta name="twitter:domain" c ...
#    window.NPR = window.NPR || {};
# NPR.ServerConstants = {"cbHost":"npr.org","webHost":"https:\/\/www.npr.org","legacyWebHost":"https:\/\/legacy.npr.org","embedHost":"https:\/\/www.npr.org","webHostSecure":"https:\/\/secure.npr.org","identityHost":"https:\/\/identity.api.npr.org","apiHost":"https:\/\/api.npr.org","serverMediaCache":"https:\/\/media.npr.org","googleAnalyticsAccount":"UA-5828686-4","nielsenSFCode":"dcr","nielsenAPN":"NPR-dcr","shouldShowHPLocalContent":true,"readingServiceHostname":"https:\/\/reading.api.npr.org","cookieDomain":".npr.org"};
# NPR.serverVars = {"storyId":"1002","refresh":1800,"facebookAppId":"138837436154588","webpackPublicPath":"https:\/\/bundles.npr.org\/dist\/bundles\/","persistenceVersion":"bd14ad2aa9056d1837bb219985fb7a8f","isBuildOut":true,"pubDate":"2016071413","pageTypeId":"2","title":"Home Page Top Stories","publisherOrgId":"1","experiments":[],"experimentTrackingHost":"https:\/\/ab.npr.org","homePageMetrics":"c1pl,c2ps,c3ps,c4ps,c5ph"};
# </script>
# <script type="text/javascript" src="https://cdn.optimizely.com/js/11107397707.js">
#    </script>
# <script type="text/javascript" src="https://static-assets.npr.org/static/javascript/lib/modernizr/modernizr.custom.js">
#    </script>
# <script>
#    !function(e){function f(a){if(c[a])return c[a].exports;var b=c[a]={exports:{},id:a,loaded:!1};return e[a].call(b.exports,b,b.exports,f),b.loaded=!0,b.exports}var a=window.webpackJsonp;window.webpackJsonp=function(d,t){for(var n,r,o=0,i=[];o<d.length;o++)r=d[o],b[r]&&i.push.apply(i,b[r]),b[r]=0;for(n in t)if(Object.prototype.hasOwnProperty.call(t,n)){var p=t[n];switch(typeof p){case"object":e[n]=function(f){var a=f.slice(1),c=f[0];return function(f,b,d){e[c].apply(this,[f,b,d].concat(a))}}(p);break;case"function":e[n]=p;break;default:e[n]=e[p]}}for(a&&a(d,t);i.length;)i.shift().call(null,f);if(t[0])return c[0]=0,f(0)};var c={},b={24:0};f.e=function(e,a){if(0===b[e])return a.call(null,f);if(void 0!==b[e])b[e].push(a);else{b[e]=[a];var c=document.getElementsByTagName("head")[0],d=document.createElement("script");d.type="text/javascript",d.charset="utf-8",d.async=!0,d.src=f.p+""+e+"."+{0:"9f02e4c28fbffd59e592",1:"3bab5ad162da0da76fd0",2:"63d51b40b9188a2c55b8",3:"b75e4d68afc411ee26fd",4:"b7610a31ac44ecd4f649",5:"038529bfa226460382d9",6:"7445bbb56c4ca0820d01",7:"4b69323389055a15a709",8:"be3f4b067c78be0aa49c",9:"bcfba50193542660fa44",10:"484b32839991dc7a78f9",11:"f0df5d4ccf7d52157932",12:"4d89e5bacbd3024d1287",13:"71ab1d5b888e17dfee47",14:"12cf032124fc029c738d",15:"7a04fe7a40e0e17cc31c",16:"a0e009cc17b82ff6878b",17:"e996c4e9fff776d4dcce",18:"7cec9ffc7236b122d7d8",19:"256359cdc724fdcc98f6",20:"8efcd4f1167e08a9f249",21:"0f79ed3a85d8e5fd2ae5",22:"496b9555ad716e47e0de",23:"e0d7a344826775a36868",25:"306afdbaf02b480f5e76",26:"8ce523180b016a4c7f5b",27:"b6aa59ce9aa54b694de2",28:"c8774bf7c2f7b1b7bfb9",29:"736355aa64afdbe023ab",30:"d9600b158a19ff991747",31:"edd332bf6f5082c09ac2",32:"24b680e366f1ac0e0afe",33:"03b136203d6ef9de3ffc",34:"738d534310c7c8ee24d2",35:"27733631191507eb4cfd",36:"10033307453f965aeecd",37:"7b0523484cdc42b166f9",38:"b27b57509820f41ae94b",39:"14136c7317d68bb89130",40:"c66b3d9a99e0a4f0a78d",41:"75bb325b70ff800c1bc3",42:"8b658e26e6e202df9880",43:"345f1bbafc660d8b4d39",44:"776bba1bfb4460609407",45:"42765b18469f05163996",46:"e04374a0fa6d1f806f2e",47:"c91b99919bdda6adc226",48:"2f3487edfd1131adac9a",49:"59f8d0a9fbd4d5ceb03e",50:"04e9c0a1776ae8f5c393",51:"e19311f9be9af9520190",52:"84d1351472f94e51ab80",53:"68c8cf1d40fb45819b76",54:"09b3f10d4826c12fd720",55:"ca72b377779f2761a013",56:"0f867cbb24c746ac31cc",57:"2fb3d0fe4f90b993439b",58:"a626c2e133d6844b59cc",59:"8915f9b3d7a0c86c3a2b",60:"260a17d2aba90520f7c1",61:"7530c0392100a5afa45d",62:"9d468fe3eb95ba4b271f",63:"75a4f7b7e81316644d20",64:"1eb4dfe9bf05072b93b8",65:"35534875e93dbe7ae5d7",66:"530086e148967527d24a",67:"04a05aa3816555ea079a",68:"07bc59f4ff3f192fac58",69:"f46c77a0b18e1067fc29",70:"f49616a8b89228a910b5",71:"ff5087f616fc6359071d",72:"ee1656b43dfbe9fa0d0a",73:"9c7fedf1a76e1f516f19",74:"8d8e41754f5876f574c0",75:"69b1972ee1e160cbb022",76:"be1482cff19202e7eddf",77:"8ea3a9a31d563c2cd540",78:"267a41184257eebac5df",79:"0e4aa14ed34323c77c74",80:"0fa58341b99a7786ff82",81:"d4fb59b98db95003f59f",82:"6efe39b766617ec27d7c",83:"2464e2f7e0c5cc59f55d"}[e]+".chunk.js",c.appendChild(d)}},f.m=e,f.c=c,f.p="/dist/bundles/"}(function(e){for(var f in e)if(Object.prototype.hasOwnProperty.call(e,f))switch(typeof e[f]){case"function":break;case"object":e[f]=function(f){var a=f.slice(1),c=e[f[0]];return function(e,f,b){c.apply(this,[e,f,b].concat(a))}}(e[f]);break;default:e[f]=e[e[f]]}return e}([]));
# </script>
# <script type="text/javascript" src="https://bundles.npr.org/dist/bundles/globalNavigationDropdowns-b6aa59ce9aa54b694de2.js">
#    </script>
# <link rel="stylesheet" data-persist="true" media="screen, print" href="https://bundles.npr.org/dist/bundles/persistent-css-76f9dc72c89ef062eaf4.css" /><link rel="stylesheet" media="screen, print" href="https://bundles.npr.org/dist/bundles/newsHp2-css-76f9dc72c89ef062eaf4.css" /><script type="text/javascript">
#    document.domain="npr.org";
# </script>
# </head><body id="news" class="news tmplHomePage agg id1002  " data-pjax-modules="util/env images/lazy-load chartbeat comscore metrics nielsen nielsenDCR copyright auto-refresh navigation/global-navigation fitvids dfp globalfooter persistent-audio player/more-options player/audio-module-clickable what-input metrics/doubleclickFloodlight metrics/facebookTracking callout/on-page-callouts global-alerts home/base jw home/header home/local-content slideshow images/enlargement images/captions images/hover-credits podcast-cards social/recaptcha"><div class="skip-links">
#       <span>Accessibility links</span>   <ul>
#             <li><a href="#mainContent" class="skiplink">Skip to main content</a></li>
#       <li><a href="https://help.npr.org/contact/s/article?name=what-are-the-keyboard-shortcuts-for-using-the-npr-org-audio-player" class="skiplink">Keyboard shortcuts for audio player</a></li>
#    </ul>
# </div>
# <header class="npr-header" id="globalheader" aria-label="NPR header">
# <nav class="navigation">
#     <div class="navigation__top-level-wrap" data-metrics-all data-metrics-category="global navigation">
#         <ul class="navigation__top-level">
#             <li class="navigation__home">
#                 <a href="/" data-metrics-action="click npr logo">
#                     <img src="https://media.npr.org/chrome_svg/npr-logo.svg" alt="NPR logo"/>
#                 </a>
#             </li>
#
#             <li id="navigation__station-mount"></li>
#
#             <li id="user-account-dropdown-mount" class="navigation__account"></li>
#
#             <li class="navigation__shop">
#                 <a href="https://shop.npr.org" data-metrics-action="click npr shop">NPR Shop</a>
#             </li>
#
#             <li id="navigation__station-donate-mount"></li>
#
#             <li class="navigation__toggle-wrap">
#                 <button id="navigation__toggle--open" class="navigation__toggle navigation__toggle--open" aria-haspopup="true" aria-expanded="false" data-metrics-action="open navigation menu">
#                     Open Navigation Menu
#                 </button>
#             </li>
#         </ul>
#     </div>
#     <section id="main-menu" class="menu menu--main" data-metrics-all data-metrics-category="global navigation">
#         <div class="menu__inner">
#             <header class="menu__header">
#                 <button id="navigation__toggle--close" class="navigation__toggle navigation__toggle--close" aria-haspopup="true" aria-expanded="true" data-metrics-action="close navigation menu">
#                     Close <span>Navigation Menu</span>
#                 </button>
#             </header>
#             <ul class="menu__list">
#                 <li class="menu__item menu__item--home">
#                     <div class="menu__item-inner"><a href="/" data-metrics-action="click npr logo">Home</a></div>
#                 </li>
#                 <li class="menu__item menu__item--news menu__item--has-submenu">
#                     <div class="menu__item-inner">
#                         <a href="/sections/news/" data-metrics-action="click news">News</a>
#                         <button class="menu__toggle-submenu" data-metrics-action="toggle news drawer">Expand/collapse submenu for News</button>
#                     </div>
#
#                     <ul class="submenu submenu--news">
#                         <li class="submenu__item"><a href="/sections/national/" data-metrics-action="click national">National</a></li>
#                         <li class="submenu__item"><a href="/sections/world/" data-metrics-action="click world">World</a></li>
#                         <li class="submenu__item"><a href="/sections/politics/" data-metrics-action="click politics">Politics</a></li>
#                         <li class="submenu__item"><a href="/sections/business/" data-metrics-action="click business">Business</a></li>
#                         <li class="submenu__item"><a href="/sections/health/" data-metrics-action="click health">Health</a></li>
#                         <li class="submenu__item"><a href="/sections/science/" data-metrics-action="click science">Science</a></li>
#                         <li class="submenu__item"><a href="/sections/technology/" data-metrics-action="click technology">Technology</a></li>
#                         <li class="submenu__item"><a href="/sections/codeswitch/" data-metrics-action="click race & culture">Race &amp; Culture</a></li>
#                     </ul>
#                 </li>
#                 <li class="menu__item menu__item--arts-life menu__item--has-submenu">
#                     <div class="menu__item-inner">
#                         <a href="/sections/arts/" data-metrics-action="click arts & life">Arts &amp; Life</a>
#                         <button class="menu__toggle-submenu" data-metrics-action="toggle arts drawer">Expand/collapse submenu for Arts &amp; Life</button>
#                     </div>
#
#                     <ul class="submenu submenu--arts-life">
#                         <li class="submenu__item"><a href="/books/" data-metrics-action="click books">Books</a></li>
#                         <li class="submenu__item"><a href="/sections/movies/" data-metrics-action="click movies">Movies</a></li>
#                         <li class="submenu__item"><a href="/sections/television/" data-metrics-action="click television">Television</a></li>
#                         <li class="submenu__item"><a href="/sections/pop-culture/" data-metrics-action="click pop culture">Pop Culture</a></li>
#                         <li class="submenu__item"><a href="/sections/food/" data-metrics-action="click food">Food</a></li>
#                         <li class="submenu__item"><a href="/sections/art-design/" data-metrics-action="click art & design">Art &amp; Design</a> </li>
#                         <li class="submenu__item"><a href="/sections/performing-arts/" data-metrics-action="click performing arts">Performing Arts</a></li>
#                     </ul>
#                 </li>
#                 <li class="menu__item menu__item--music menu__item--has-submenu">
#                     <div class="menu__item-inner">
#                         <a href="/music/" data-metrics-action="click music">Music</a>
#                         <button class="menu__toggle-submenu" data-metrics-action="toggle music drawer">Expand/collapse submenu for Music</button>
#                     </div>
#
#                     <ul class="submenu submenu--music"><li class="submenu__item">
#     <a href="https://www.npr.org/series/tiny-desk-concerts/" data-metrics-action="click tiny desk">
#         Tiny Desk
#     </a>
# </li><li class="submenu__item">
#     <a href="https://www.npr.org/sections/allsongs/" data-metrics-action="click all songs considered">
#         All Songs Considered
#     </a>
# </li><li class="submenu__item">
#     <a href="https://www.npr.org/sections/music-news/" data-metrics-action="click music news">
#         Music News
#     </a>
# </li><li class="submenu__item">
#     <a href="https://www.npr.org/sections/new-music/" data-metrics-action="click new music">
#         New Music
#     </a>
# </li><li class="submenu__item">
#     <a href="https://www.npr.org/sections/music-features" data-metrics-action="click music features">
#         Music Features
#     </a>
# </li><li class="submenu__item">
#     <a href="https://www.npr.org/series/770565791/npr-music-live-sessions" data-metrics-action="click live sessions">
#         Live Sessions
#     </a>
# </li></ul>
#
#                 </li>
#                 <li class="menu__item menu__item--shows-podcasts menu__item--has-submenu">
#                     <div class="menu__item-inner">
#                         <a href="/programs/" data-metrics-action="click shows & podcasts">Shows &amp; Podcasts</a>
#                         <button class="menu__toggle-submenu" data-metrics-action="toggle programs &amp; podcasts drawer">Expand/collapse submenu for Shows &amp; Podcasts</button>
#                     </div>
#
#                     <div class="submenu submenu--shows-podcasts">
#                         <span class="submenu__category submenu__category--daily">Daily</span>
#                         <ul class="submenu__list submenu__list--daily">
#                             <li class="submenu__item submenu__item--timed submenu__item--weekday hidden">
#                                 <a href="/programs/morning-edition/" data-metrics-action="click morning edition">
#                                     <img src="https://media.npr.org/chrome/programs/logos/morning-edition.jpg" alt="" />
#                                     Morning Edition
#                                 </a>
#                             </li>
#                             <li class="submenu__item submenu__item--timed submenu__item--saturday hidden" >
#                                 <a href="/programs/weekend-edition-saturday/" data-metrics-action="click weekend edition saturday">
#                                     <img src="https://media.npr.org/assets/img/2019/02/26/we_otherentitiestemplatesat_sq-cbde87a2fa31b01047441e6f34d2769b0287bcd4-s100-c85.png" alt="" />
#                                     Weekend Edition Saturday
#                                 </a>
#                             </li>
#                             <li class="submenu__item submenu__item--timed submenu__item--sunday hidden">
#                                 <a href="/programs/weekend-edition-sunday/" data-metrics-action="click weekend edition sunday">
#                                     <img src="https://media.npr.org/assets/img/2019/02/26/we_otherentitiestemplatesun_sq-4a03b35e7e5adfa446aec374523a578d54dc9bf5-s100-c85.png" alt="" />
#                                     Weekend Edition Sunday
#                                 </a>
#                             </li>
#                             <li class="submenu__item">
#                                 <a href="/programs/all-things-considered/" data-metrics-action="click all things considered">
#                                     <img src="https://media.npr.org/chrome/programs/logos/all-things-considered.png" alt="" />
#                                     All Things Considered
#                                 </a>
#                             </li>
#                             <li class="submenu__item">
#                                 <a href="/programs/fresh-air/" data-metrics-action="click fresh air">
#                                     <img src="https://media.npr.org/chrome/programs/logos/fresh-air.png" alt="" />
#                                     Fresh Air
#                                 </a>
#                             </li>
#                             <li class="submenu__item">
#                                 <a href="/podcasts/510318/up-first" data-metrics-action="click up first">
#                                     <img src="https://media.npr.org/chrome/programs/logos/up-first.jpg?version=2" alt="" />
#                                     Up First
#                                 </a>
#                             </li>
#                         </ul>
#                         <span class="submenu__category submenu__category--featured">Featured</span>
#
#                         <ul class="submenu__list submenu__list--featured"><li class="submenu__item">
#     <a href="https://www.npr.org/podcasts/510317/its-been-a-minute-with-sam-sanders" data-metrics-action="click it's been a minute with sam sanders">
#         <img src="https://media.npr.org/assets/img/2020/05/29/ibam_arttile_final_sq-b6691366c421f19f130bd0beef01c1597c57bdf3.png?s=100" alt="" />
#         It's Been a Minute with Sam Sanders
#     </a>
# </li><li class="submenu__item">
#     <a href="https://www.npr.org/podcasts/510312/codeswitch" data-metrics-action="click code switch">
#         <img src="https://media.npr.org/assets/img/2020/03/24/undefined_sq-63f9f4b46bb9031d67f9785b66818f4befbab8bc.jpg?s=100" alt="" />
#         Code Switch
#     </a>
# </li><li class="submenu__item">
#     <a href="https://www.npr.org/podcasts/510333/throughline" data-metrics-action="click throughline">
#         <img src="https://media.npr.org/assets/img/2019/01/28/nprthroughline_podcasttile_sq-3bddbe49827adf54bdbc1f94b40fc61d581704f6.png?s=100" alt="" />
#         Throughline
#     </a>
# </li><li class="submenu__item">
#     <a href="https://www.npr.org/podcasts/510355/considerthis" data-metrics-action="click consider this from npr ">
#         <img src="https://media.npr.org/assets/img/2020/06/28/consider-this_podcast-tile_sq-ad4dd62fac1bc1f945b03fcaff3c129fc8b4d640.png?s=100" alt="" />
#         Consider This from NPR
#     </a>
# </li></ul>
#
#                         <ul class="submenu__list submenu__list--directories">
#                             <li class="submenu__item"><a href="/programs/" data-metrics-action="click all programs">More Shows &amp; Podcasts</a></li>
#                         </ul>
#                     </div>
#                 </li>
#                 <li class="menu__item menu__item--search">
#                     <div class="menu__item-inner">
#                         <a href="/search" id="navigation_dropdown-search" data-metrics-action="click search">Search</a>
#                     </div>
#                 </li>
#                 <li id="user-account-dropdown-mount-two" class="menu__item menu__item--account"></li>
#                 <li class="menu__item menu__item--shop">
#                     <div class="menu__item-inner">
#                         <a href="https://shop.npr.org" data-metrics-action="click npr shop">NPR Shop</a>
#                     </div>
#                 </li>
#             </ul>
#         </div>
#     </section>
#     <section class="menu menu--music" data-metrics-all data-metrics-category="music ecosystem navigation">
#         <div class="menu__list-wrap">
#             <ul class="menu__list menu__list--ecosystem menu__list--music">
#                 <li class="menu__item menu__item--music-home">
#                     <a href="/music/" data-metrics-action="click npr music logo">
#                         <img src="https://media.npr.org/chrome_svg/music-logo-dark.svg" class="music-logo"  alt="NPR Music" />
#                         <img src="https://media.npr.org/chrome_svg/music-logo-light.svg" class="music-logo-alt" alt="NPR Music" />
#                     </a>
#                 </li>
#
#                 <li class="menu__item">
#     <a href="https://www.npr.org/series/tiny-desk-concerts/" data-metrics-action="click tiny desk">
#         Tiny Desk
#     </a>
# </li><li class="menu__item">
#     <a href="https://www.npr.org/sections/allsongs/" data-metrics-action="click all songs considered">
#         All Songs Considered
#     </a>
# </li><li class="menu__item">
#     <a href="https://www.npr.org/sections/music-news/" data-metrics-action="click music news">
#         Music News
#     </a>
# </li><li class="menu__item">
#     <a href="https://www.npr.org/sections/new-music/" data-metrics-action="click new music">
#         New Music
#     </a>
# </li><li class="menu__item">
#     <a href="https://www.npr.org/sections/music-features" data-metrics-action="click music features">
#         Music Features
#     </a>
# </li><li class="menu__item">
#     <a href="https://www.npr.org/series/770565791/npr-music-live-sessions" data-metrics-action="click live sessions">
#         Live Sessions
#     </a>
# </li>
#             </ul>
#         </div>
#     </section>
#     <section class="menu menu--about" data-metrics-all data-metrics-category="about ecosystem navigation">
#         <div class="menu__list-wrap">
#             <ul class="menu__list menu__list--ecosystem menu__list--about">
#                 <li class="menu__item menu__item--about-home"><a href="/about/" data-metrics-action="click about npr">About NPR</a></li>
#                 <li class="menu__item menu__item--about-overview"><a href="/overview/" data-metrics-action="click overview">Overview</a></li>
#                 <li class="menu__item menu__item--about-support"><a href="/support/" data-metrics-action="click support">Support</a></li>
#                 <li class="menu__item menu__item--about-careers"><a href="/careers/" data-metrics-action="click careers">Careers</a></li>
#                 <li class="menu__item menu__item--about-connect"><a href="/connect/" data-metrics-action="click connect">Connect</a></li>
#                 <li class="menu__item menu__item--about-press"><a href="/press/" data-metrics-action="click press">Press</a></li>
#                 <li class="menu__item menu__item--about-ethics"><a href="/ethics/" data-metrics-action="click ethics">Ethics</a></li>
#             </ul>
#         </div>
#     </section>
# </nav></header><main aria-label="main content"><div class="speakable">
#       <b data-is-speakable>NPR : National Public Radio : News & Analysis, World, US, Music & Arts</b>   <b data-is-speakable>NPR delivers breaking national and world news. Also top stories from business, politics, health, science, technology, music, arts and culture. Subscribe to podcasts and RSS feeds.</b>
# </div>
# <div id="wrapper">
#       <section id="main-section"><a id="mainContent"></a><div id="experimentWrap">
#       <style type="text/css">article.experimentVariant { display: none; }
# </style>   <script type='text/javascript'>
#     // helper functions
#     var generateIdForExperimentVariant = function(experimentId, variantId) {
#       return 'article.experimentVariant#story' + experimentId.toString() +  variantId.toString();
#     };
#
#     NPR.serverVars.experimentMetrics = [];
#     var experimentStyles = '';
#
#     var experimentList = NPR.serverVars.experiments || [];
#     experimentList.forEach(function(experiment) {
#         var experimentId = experiment.id;
#         var experimentStoryId = experiment.storyId;
#         var variants = experiment.variants;
#
#         if (!variants || !variants.length) {
#             return;
#         }
#
#         var randomValue =  Math.random();
#
#         // select a variant weighted on the frequencies in the variant metadata
#         // the frequencies are between 0 and 1, and the sum of the frequencies add up to 1
#         var weightedSum = 0;
#         var variantId = variants[0].id;
#         var pickedOne = false;
#         for (var index = 0; index < variants.length; index++) {
#             var variant = variants[index];
#             weightedSum += parseFloat(variant.freq);
#
#             if (!pickedOne && randomValue <= weightedSum) {
#                 variantId = variant.id;
#                 pickedOne = true;
#                 experimentStyles += generateIdForExperimentVariant(experimentStoryId, variant.id) + ' { display:block;} \n';
#             }
#             else {
#                 experimentStyles += generateIdForExperimentVariant(experimentStoryId, variant.id) + ' { display:none;} \n';
#             }
#         }
#         // store info for use by Google Analytics later
#         NPR.serverVars.experimentMetrics.push([experimentId,variantId,experimentStoryId]);
#
#         // https://www.admonsters.com/blog/pixel-delivery-best-practices
#         // http://stackoverflow.com/a/22419389
#         (new Image()).src = NPR.serverVars.experimentTrackingHost + '/abtesting/experiments/' + experimentId + '/variants/' +  variantId + '/impression.gif';
#     });
#
#     // attaching the live click handler
#     document.addEventListener('click', function (event) {
#         if (NPR.serverVars.experimentMetrics && NPR.serverVars.experimentMetrics.constructor === Array) {
#             NPR.serverVars.experimentMetrics.forEach(function (experimentVariant) {
#                 var experimentId = experimentVariant[0];
#                 var variantId = experimentVariant[1];
#                 var experimentStoryId = experimentVariant[2];
#
#                 var idToSearchFor = 'story' + experimentStoryId + variantId;
#                 var el = event.target
#                         , found;
#
#                 while (el && !(found = el.id === idToSearchFor)) {
#                     el = el.parentElement;
#                 }
#
#                 if (found) {
#                     (new Image()).src = NPR.serverVars.experimentTrackingHost + '/abtesting/experiments/' + experimentId + '/variants/' + variantId + '/click.gif';
#                 }
#             });
#         }
#     });
#
#     var styleDiv = document.createElement('div');
#     styleDiv.innerHTML = '<style>' + experimentStyles + '</style>';
#     document.getElementById('experimentWrap').appendChild(styleDiv.childNodes[0]);
# </script>
# </div>
#
# <!-- END ID="EXPERIMENTWRAP" -->
# <div id="contentWrap">
#       <div class="stories-wrap stories-wrap-featured" data-metrics-category="Curated List">
#             <article class="hp-item volume-low post-type-standard has-image "  id="story897911727"  >
#
#
#
#     <div class="story-wrap">
#
#         <figure class="thumb-image">
#             <div class="bucketwrap homeThumb">
#                 <div class="imagewrap" data-crop-type="wide">
#     <a href="https://www.npr.org/2020/08/01/897911727/biden-wants-the-fed-to-help-close-racial-economic-gaps-how-would-that-work" data-metrics='{"action":"Click Story 1"}' >
#         <img src="https://media.npr.org/assets/img/2020/08/01/ap_20210746068616_wide-a72c5095d2b9a8debe3475b077996387d3656868-s400-c15.jpg" data-original="https://media.npr.org/assets/img/2020/08/01/ap_20210746068616_wide-a72c5095d2b9a8debe3475b077996387d3656868-s400.jpg" class="img lazyOnLoad"  alt="Biden Wants The Fed To Help Close Racial Economic Gaps. How Would That Work?" loading="lazy" />
#     </a>
# </div>
# <div class="credit-caption">
#     <div class="caption-wrap">
#         <div class="caption" aria-label="Image caption">
#             <p>
#                 Democratic presidential candidate former Vice President Joe Biden speaks at a campaign event in Wilmington, Del., Tuesday, July 28, 2020.
#
#                 <b class="credit" aria-label="Image credit">
#
#                     Andrew Harnik/AP
#
#                 </b>
#                 <b class="hide-caption"><b>hide caption</b></b>
#             </p>
#         </div>
#
#
#             <b class="toggle-caption"><b>toggle caption</b></b>
#     </div>
#
#     <span class="credit" aria-label="Image credit">
#
#         Andrew Harnik/AP
#
#     </span>
# </div>
#
#             </div>
#         </figure>
#
#
#         <div class="story-text">
#                 <div class="slug-wrap">
#
#                     <h2 class="slug">
#                         <a href="https://www.npr.org/sections/elections/" data-metrics='{"action":"Click Slug"}'>
#                         Elections
#                         </a>
#                     </h2>
#                 </div>
#             <a href="https://www.npr.org/2020/08/01/897911727/biden-wants-the-fed-to-help-close-racial-economic-gaps-how-would-that-work" data-metrics='{"action" : "Click Story 1"}'>
#                 <h3 class="title">Biden Wants The Fed To Help Close Racial Economic Gaps. How Would That Work?</h3>
#             </a>
#
#
#             <a href="https://www.npr.org/2020/08/01/897911727/biden-wants-the-fed-to-help-close-racial-economic-gaps-how-would-that-work" data-metrics='{"action" : "Click Story 1"}'>
#                 <p class="teaser">The central bank has blunt instruments at its disposal, which are not tailored to economics of different racial groups. Biden wants the Fed to more explicitly factor in Black and Hispanic outcomes.</p>
#             </a>
#         </div> <!-- /.story-text -->
#     </div> <!-- /.story-wrap -->
# </article>
#       <section class="featured-group"><article class="hp-item hp-item-basic post-type-standard has-image has-status "  id="story896882268"  >
#     <div class="story-wrap">
#             <figure class="thumb-image">
#                 <div class="bucketwrap homeThumb">
#                     <div class="imagewrap" data-crop-type="wide">
#     <a href="https://www.npr.org/2020/07/31/896882268/one-mans-covid-19-death-raises-the-worst-fears-of-many-people-with-disabilities" data-metrics='{"action":"Click Story 2"}' >
#         <img src="https://media.npr.org/assets/img/2020/07/31/mh-img_0531_wide-23fb7c2816775ba86bab7182e9f84b97c44d912b-s400-c15.jpg" data-original="https://media.npr.org/assets/img/2020/07/31/mh-img_0531_wide-23fb7c2816775ba86bab7182e9f84b97c44d912b-s400.jpg" class="img lazyOnLoad"  alt="One Man's COVID-19 Death Raises The Worst Fears Of Many People With Disabilities" loading="lazy" />
#     </a>
# </div>
# <div class="credit-caption">
#     <div class="caption-wrap">
#         <div class="caption" aria-label="Image caption">
#             <p>
#                 Melissa Hickson says no one asked her husband Michael, shown here with stepdaughter Mia, if he wanted to keep getting treatment. "He would say: 'I want to live. I love my family and my children ... that's the reason for the three years I have fought to survive,'" she says.
#
#                 <b class="credit" aria-label="Image credit">
#
#                     Melissa Hickson
#
#                 </b>
#                 <b class="hide-caption"><b>hide caption</b></b>
#             </p>
#         </div>
#
#
#             <b class="toggle-caption"><b>toggle caption</b></b>
#     </div>
#
#     <span class="credit" aria-label="Image credit">
#
#         Melissa Hickson
#
#     </span>
# </div>
#
#                 </div>
#             </figure>
#
#         <div class="story-text">
#                 <div class="slug-wrap">
#
#                         <h2 class="slug">
#                             <a href="https://www.npr.org/sections/investigations/" data-metrics='{"action":"Click Slug"}'>
#                             Investigations
#                             </a>
#                         </h2>
#                 </div>
#             <a href="https://www.npr.org/2020/07/31/896882268/one-mans-covid-19-death-raises-the-worst-fears-of-many-people-with-disabilities" data-metrics='{"action" : "Click Story 2"}'>
#             <h3 class="title">One Man's COVID-19 Death Raises The Worst Fears Of Many People With Disabilities</h3>
#             </a>
#
#         </div> <!-- /.story-text -->
#     </div> <!-- /.story-wrap -->
# </article>
# <article class="hp-item hp-item-basic post-type-standard has-image "  id="story897803230"  >
#     <div class="story-wrap">
#             <figure class="thumb-image">
#                 <div class="bucketwrap homeThumb">
#                     <div class="imagewrap" data-crop-type="wide">
#     <a href="https://www.npr.org/2020/07/31/897803230/floridas-gov-desantis-declares-emergency-as-hurricane-isaias-approaches" data-metrics='{"action":"Click Story 3"}' >
#         <img src="https://media.npr.org/assets/img/2020/07/31/isaias-cone-uncertainty_wide-38fe1696330c4323c128ad52d638ccf4c519221e-s400-c15.png" data-original="https://media.npr.org/assets/img/2020/07/31/isaias-cone-uncertainty_wide-38fe1696330c4323c128ad52d638ccf4c519221e-s400.png" class="img lazyOnLoad"  alt="Florida's Gov. DeSantis Declares Emergency As Hurricane Isaias Closes In" loading="lazy" />
#     </a>
# </div>
# <div class="credit-caption">
#     <div class="caption-wrap">
#         <div class="caption" aria-label="Image caption">
#             <p>
#                 Hurricane Isaias will maintain its hurricane status for several days as it passes along Florida's central Atlantic coast, the National Hurricane Center says. The storm's forecast cone predicts it will hug the southeastern U.S. coastline.
#
#                 <b class="credit" aria-label="Image credit">
#
#                     National Weather Service
#
#                 </b>
#                 <b class="hide-caption"><b>hide caption</b></b>
#             </p>
#         </div>
#
#
#             <b class="toggle-caption"><b>toggle caption</b></b>
#     </div>
#
#     <span class="credit" aria-label="Image credit">
#
#         National Weather Service
#
#     </span>
# </div>
#
#                 </div>
#             </figure>
#
#         <div class="story-text">
#                 <div class="slug-wrap">
#
#                         <h2 class="slug">
#                             <a href="https://www.npr.org/sections/weather" data-metrics='{"action":"Click Slug"}'>
#                             Weather
#                             </a>
#                         </h2>
#                 </div>
#             <a href="https://www.npr.org/2020/07/31/897803230/floridas-gov-desantis-declares-emergency-as-hurricane-isaias-approaches" data-metrics='{"action" : "Click Story 3"}'>
#             <h3 class="title">Florida's Gov. DeSantis Declares Emergency As Hurricane Isaias Closes In</h3>
#             </a>
#
#         </div> <!-- /.story-text -->
#     </div> <!-- /.story-wrap -->
# </article>
# <article class="hp-item hp-item-basic post-type-standard has-image "  id="story897752390"  >
#     <div class="story-wrap">
#             <figure class="thumb-image">
#                 <div class="bucketwrap homeThumb">
#                     <div class="imagewrap" data-crop-type="wide">
#     <a href="https://www.npr.org/2020/07/31/897752390/microsoft-in-talks-to-buy-teen-fav-tiktok-as-trump-ramps-up-pressure" data-metrics='{"action":"Click Story 4"}' >
#         <img src="https://media.npr.org/assets/img/2020/07/31/gettyimages-1221110459_wide-3055a6cd8ae5aa830c8e32de3167a0860905ee60-s400-c15.jpg" data-original="https://media.npr.org/assets/img/2020/07/31/gettyimages-1221110459_wide-3055a6cd8ae5aa830c8e32de3167a0860905ee60-s400.jpg" class="img lazyOnLoad"  alt="Trump Says He'll Ban TikTok From U.S. As Soon As Saturday" loading="lazy" />
#     </a>
# </div>
# <div class="credit-caption">
#     <div class="caption-wrap">
#         <div class="caption" aria-label="Image caption">
#             <p>
#                 TikTok has been under fire in Washington, as the Trump administration and some Democrats in Congress have been raising national security concerns about the Chinese-owned app.
#
#                 <b class="credit" aria-label="Image credit">
#
#                     Photo Illustration by Rafael Henrique/SOPA Images/LightRocket via Getty Images
#
#                 </b>
#                 <b class="hide-caption"><b>hide caption</b></b>
#             </p>
#         </div>
#
#
#             <b class="toggle-caption"><b>toggle caption</b></b>
#     </div>
#
#     <span class="credit" aria-label="Image credit">
#
#         Photo Illustration by Rafael Henrique/SOPA Images/LightRocket via Getty Images
#
#     </span>
# </div>
#
#                 </div>
#             </figure>
#
#         <div class="story-text">
#                 <div class="slug-wrap">
#
#                         <h2 class="slug">
#                             <a href="https://www.npr.org/sections/technology/" data-metrics='{"action":"Click Slug"}'>
#                             Technology
#                             </a>
#                         </h2>
#                 </div>
#             <a href="https://www.npr.org/2020/07/31/897752390/microsoft-in-talks-to-buy-teen-fav-tiktok-as-trump-ramps-up-pressure" data-metrics='{"action" : "Click Story 4"}'>
#             <h3 class="title">Trump Says He'll Ban TikTok From U.S. As Soon As Saturday</h3>
#             </a>
#
#         </div> <!-- /.story-text -->
#     </div> <!-- /.story-wrap -->
# </article>
# </section>
# <!-- END CLASS="FEATURED-GROUP" -->
#    </div>
#
# <!-- END CLASS="STORIES-WRAP STORIES-WRAP-FEATURED" DATA-METRICS-CATEGORY="CURATED LIST" -->
#    <div class="centerstage-outer-wrap">
#             <p class="centerstage-sponsor-language"><span>More NPR content after sponsor message</span></p>      <aside id="ad-centerstage-wrap" aria-label="advertisement">
#
#
#     <div id="ad-centerstage-homepage" class="ad-centerstage" data-ad-config='{"network":"\/6735\/","site":{"default":"n6735.NPR","mobile":"n6735.NPRMOBILE"},"zone":"homepage","targets":{"testserver":"false","isPodcastEpisode":"false","storyId":"1002"},"location":"centerstage","deferred":false,"isBetweenContent":false,"isAggSponsorship":false,"borderClass":""}'></div>
#
# </aside>
#    </div>
#
# <!-- END CLASS="CENTERSTAGE-OUTER-WRAP" -->
#    <section id="local-content-mount"></section>
# <!-- END ID="LOCAL-CONTENT-MOUNT" -->
#    <div class="stories-wrap stories-wrap-two" data-metrics-category="Curated List">
#             <article class="hp-item volume-high post-type-standard has-image has-affiliation "  id="story894320590"  >
#
#
#
#
#         <div class="story-wrap">
#
#
#             <figure class="head-image">
#                 <div class="bucketwrap homeLarge">
#                     <div class="imagewrap" data-crop-type="wide">
#     <a href="https://www.npr.org/sections/health-shots/2020/08/01/894320590/in-rural-missouri-latinx-communities-learn-to-contain-and-cope-with-the-coronavi" data-metrics='{"action":"Click Story 5"}' >
#         <img src="https://media.npr.org/assets/img/2020/08/01/gettyimages-1224644759_wide-8b7e402017460c0657864ae3f168cab2841ec5dc-s900-c15.jpg" data-original="https://media.npr.org/assets/img/2020/08/01/gettyimages-1224644759_wide-8b7e402017460c0657864ae3f168cab2841ec5dc-s900.jpg" class="img lazyOnLoad"  alt="In Rural Missouri, Latinx Communities Learn To Contain And Cope With The Coronavirus " loading="lazy" />
#     </a>
# </div>
# <div class="credit-caption">
#     <div class="caption-wrap">
#         <div class="caption" aria-label="Image caption">
#             <p>
#                 The industrial complex in Carthage where many Latinx residents work is a half-mile walk from the town square.
#
#                 <b class="credit" aria-label="Image credit">
#
#                     Terra Fondriest for The Washington Post via Getty Images
#
#                 </b>
#                 <b class="hide-caption"><b>hide caption</b></b>
#             </p>
#         </div>
#
#
#             <b class="toggle-caption"><b>toggle caption</b></b>
#     </div>
#
#     <span class="credit" aria-label="Image credit">
#
#         Terra Fondriest for The Washington Post via Getty Images
#
#     </span>
# </div>
#
#                 </div>
#             </figure>
#
#
#             <div class="story-text-wrap">
#                 <div class="story-text">
#                         <div class="slug-wrap">
#
#                                 <h2 class="slug">
#                                     <a href="https://www.npr.org/sections/health-shots/" data-metrics='{"action":"Click Slug"}'>
#                                     Shots - Health News
#                                     </a>
#                                 </h2>
#                         </div>
#                     <a href="https://www.npr.org/sections/health-shots/2020/08/01/894320590/in-rural-missouri-latinx-communities-learn-to-contain-and-cope-with-the-coronavi" data-metrics='{"action" : "Click Story 5"}'>
#                         <h3 class="title">In Rural Missouri, Latinx Communities Learn To Contain And Cope With The Coronavirus</h3>
#                     </a>
#
#                         <b class="affiliation ">
#                             KBIA
#                         </b>
#
#                     <a href="https://www.npr.org/sections/health-shots/2020/08/01/894320590/in-rural-missouri-latinx-communities-learn-to-contain-and-cope-with-the-coronavi" data-metrics='{"action" : "Click Story 5"}'>
#                         <p class="teaser">Rural Carthage, Mo., is home to a growing community of Latin American immigrants. Language barriers and economic stress have made it harder to slow the spread of COVID-19.</p>
#                     </a>
#                 </div> <!-- /.story-text -->
#
#             </div> <!-- /.story-text-wrap -->
#         </div> <!-- /.story-wrap -->
#
# </article>
#       <section class="attachment-group">
#   <article class="hp-item volume-low post-type-standard has-attachment has-image "  id="story897724197"  >
#
#
#
#     <div class="story-wrap">
#
#         <figure class="thumb-image">
#             <div class="bucketwrap homeThumb">
#                 <div class="imagewrap" data-crop-type="wide">
#     <a href="https://www.npr.org/2020/07/31/897724197/citing-election-delay-tweet-influential-trump-ally-now-demands-his-re-impeachmen" data-metrics='{"action":"Click Story 6"}' >
#         <img src="https://media.npr.org/assets/img/2020/07/31/ap_20213664206566_wide-9651391699a24c9d62a0bff43cc4ea7e01eb97ea-s400-c15.jpg" data-original="https://media.npr.org/assets/img/2020/07/31/ap_20213664206566_wide-9651391699a24c9d62a0bff43cc4ea7e01eb97ea-s400.jpg" class="img lazyOnLoad"  alt="Citing Election Delay Tweet, Influential Trump Ally Now Demands His Re-Impeachment" loading="lazy" />
#     </a>
# </div>
# <div class="credit-caption">
#     <div class="caption-wrap">
#         <div class="caption" aria-label="Image caption">
#             <p>
#                 President Donald Trump, shown here on Friday, floated the idea of delaying the election on Thursday. That prompted criticism from the co-founder of the Federalist Society.
#
#                 <b class="credit" aria-label="Image credit">
#
#                     Alex Brandon/AP
#
#                 </b>
#                 <b class="hide-caption"><b>hide caption</b></b>
#             </p>
#         </div>
#
#
#             <b class="toggle-caption"><b>toggle caption</b></b>
#     </div>
#
#     <span class="credit" aria-label="Image credit">
#
#         Alex Brandon/AP
#
#     </span>
# </div>
#
#             </div>
#         </figure>
#
#
#         <div class="story-text">
#                 <div class="slug-wrap">
#
#                     <h2 class="slug">
#                         <a href="https://www.npr.org/sections/elections/" data-metrics='{"action":"Click Slug"}'>
#                         Elections
#                         </a>
#                     </h2>
#                 </div>
#             <a href="https://www.npr.org/2020/07/31/897724197/citing-election-delay-tweet-influential-trump-ally-now-demands-his-re-impeachmen" data-metrics='{"action" : "Click Story 6"}'>
#                 <h3 class="title">Citing Election Delay Tweet, Influential Trump Ally Now Demands His Re-Impeachment</h3>
#             </a>
#
#
#             <a href="https://www.npr.org/2020/07/31/897724197/citing-election-delay-tweet-influential-trump-ally-now-demands-his-re-impeachmen" data-metrics='{"action" : "Click Story 6"}'>
#                 <p class="teaser">President Trump's suggestion that the November election be delayed spurs Federalist Society co-founder Steven Calabresi to call for his removal from office.</p>
#             </a>
#         </div> <!-- /.story-text -->
#     </div> <!-- /.story-wrap -->
# </article>
# <article class="hp-item attachment volume-low">
#     <a class="story-wrap" href="https://www.npr.org/2020/07/30/897111969/trump-floats-delaying-the-election-it-would-require-a-change-in-law" data-metrics='{"action" : "Click Attached Story 6"}'>
#         <div class="story-text">
#             <h3 class="title">Trump Floats Delaying The Election. It Would Require A Change In Law</h3>
#         </div>
#     </a>
# </article>
# <article class="hp-item attachment volume-low">
# ...
#       <span class="playlist-formatDuration">00:08:28</span>   <div class="playlist-item-playing">
#          </div>
#
# <!-- END CLASS="PLAYLIST-ITEM-PLAYING" -->
#    <img class="playlist-thumbnail" src="https://media.npr.org/assets/img/2020/07/10/tommischyussefdayes_thumb_wide-b4b249230529d7fd58193e93741e751c3827755c-s800-c85.jpg" loading="lazy" />
# </div>
#
# <!-- END CLASS="PLAYLIST-THUMBNAIL-WRAPPER" -->
# <p>Tom Misch And Yussef Dayes: Tiny Desk (Home) Concert</p></a></li>
#          <li class="playlist-item" data-metrics='{"action":"select video from coming up","category":"JW Player Video","label":"Jacob Collier: Tiny Desk (Home) Concert", "type":"customEvent", "customDimensions":{ "dimension47":"/2020/07/09/888764856/jacob-collier-tiny-desk-home-concert","dimension48":"Jacob Collier: Tiny Desk (Home) Concert","dimension49":"965" }}' ><a class="playlist-item-link" tabindex="0" data-mediaid="/2020/07/09/888764856/jacob-collier-tiny-desk-home-concert" ><div class="playlist-thumbnail-wrapper">
#       <span class="playlist-formatDuration">00:16:05</span>   <div class="playlist-item-playing">
#          </div>
#
# <!-- END CLASS="PLAYLIST-ITEM-PLAYING" -->
#    <img class="playlist-thumbnail" src="https://media.npr.org/assets/img/2020/07/08/jacob-copy_wide-4b37c9d6b246e79a32d117017340573c0d04e9cb-s800-c85.jpg" loading="lazy" />
# </div>
#
# <!-- END CLASS="PLAYLIST-THUMBNAIL-WRAPPER" -->
# <p>Jacob Collier: Tiny Desk (Home) Concert</p></a></li>
#       </ul>
#       <div class="playlist__gradient playlist__gradient--bottom">
#                </div>
#    </div>
#
# <!-- END CLASS="PLAYLIST-WRAPPER" -->
# </div>
#
# <!-- END ID="JWPLAYLIST656281336" CLASS="PLAYER-PLAYLIST-WRAPPER" -->
# <div id='jwPlayerList656281336' data-playlist-id='jwPlaylist656281336' data-player-id='player-shelf656281336' data-jwplayer-playlist='[{"skinSource":"https:\/\/static-assets.npr.org\/static\/javascript\/jwplayer\/skins\/npr.css","flashPlayer":"https:\/\/static-assets.npr.org\/static\/javascript\/jwplayer\/jwplayer.flash.swf","width":"100%","height":"100%","isLive":true,"image":"https:\/\/media.npr.org\/assets\/img\/2020\/07\/28\/lyric-copy_wide-5f9bc7d9e88451bf6c3547e75b59467de4434cfe-s800-c85.jpg","primary":"html5","sources":[{"file":"https:\/\/cdn.jwplayer.com\/manifests\/bvJRK7DM.m3u8","label":null,"type":"hls"}],"tracks":[],"description":"The Boston-born, Los Angeles-based rapper does it all in this performance for our Tiny Desk quarantine series.","title":"Lyric Jones: Tiny Desk (Home) Concert","videoPrerollAdUrl":"https:\/\/pubads.g.doubleclick.net\/gampad\/ads?env=vp&gdfp_req=1&impl=s&unviewed_position_start=1&output=vast&iu=%2F6735%2Fn6735.NPR.MUSIC%2FMusic_Music_Videos&sz=400x300&correlator=1866176412&cust_params=testserver%3Dfalse%26isPodcastEpisode%3Dfalse%26storyId%3D895844885%26agg%3D820178308%2C92071316%2C656281336%2C314884013%2C164710643%26artists%3D896600240%26genres%3DHip_Hop%26jwPlaylistId%3D656281336","shareUrl":"https:\/\/www.npr.org\/2020\/07\/29\/895844885\/lyric-jones-tiny-desk-home-concert","embedLink":"https:\/\/www.npr.org\/embedded-video?storyId=895844885&mediaId=","webHost":"https:\/\/www.npr.org","duration":"1305","mediaid":"\/2020\/07\/29\/895844885\/lyric-jones-tiny-desk-home-concert","resId":"895851878"},{"skinSource":"https:\/\/static-assets.npr.org\/static\/javascript\/jwplayer\/skins\/npr.css","flashPlayer":"https:\/\/static-assets.npr.org\/static\/javascript\/jwplayer\/jwplayer.flash.swf","width":"100%","height":"100%","isLive":true,"image":"https:\/\/media.npr.org\/assets\/img\/2020\/07\/27\/thaonguyen_tdhc_thumb_wide-c9fc6d8cb7fe6eb80a515dfe60b0e141e5e3c919-s800-c85.jpg","primary":"html5","sources":[{"file":"https:\/\/cdn.jwplayer.com\/manifests\/zTYOTET5.m3u8","label":null,"type":"hls"}],"tracks":[],"description":"Thao is joined by two cellists in this remarkable set for our Tiny Desk quarantine series.","title":"Thao Nguyen: Tiny Desk (Home) Concert","videoPrerollAdUrl":"https:\/\/pubads.g.doubleclick.net\/gampad\/ads?env=vp&gdfp_req=1&impl=s&unviewed_position_start=1&output=vast&iu=%2F6735%2Fn6735.NPR.MUSIC%2FMusic_Music_Videos&sz=400x300&correlator=810660116&cust_params=testserver%3Dfalse%26isPodcastEpisode%3Dfalse%26storyId%3D895809984%26agg%3D820178308%2C92071316%2C656281336%2C314884013%2C164710643%26genres%3DFolk%2CRock%26jwPlaylistId%3D656281336","shareUrl":"https:\/\/www.npr.org\/2020\/07\/28\/895809984\/thao-nguyen-tiny-desk-home-concert","embedLink":"https:\/\/www.npr.org\/embedded-video?storyId=895809984&mediaId=","webHost":"https:\/\/www.npr.org","duration":null,"mediaid":"\/2020\/07\/28\/895809984\/thao-nguyen-tiny-desk-home-concert","resId":"895833384"},{"skinSource":"https:\/\/static-assets.npr.org\/static\/javascript\/jwplayer\/skins\/npr.css","flashPlayer":"https:\/\/static-assets.npr.org\/static\/javascript\/jwplayer\/jwplayer.flash.swf","width":"100%","height":"100%","isLive":true,"image":"https:\/\/media.npr.org\/assets\/img\/2020\/07\/24\/lucinda-copy_wide-e6dea4941ad6862d6b601725d919f2cc21db5bd1-s800-c85.jpg","primary":"html5","sources":[{"file":"https:\/\/cdn.jwplayer.com\/manifests\/sZCQt6Hw.m3u8","label":null,"type":"hls"}],"tracks":[],"description":"Lucinda Williams and her guitar mate, Stuart Mathis, set up shop for a Tiny Desk home concert at Thirty Tigers&#39 headquarters in Nashville.","title":"Watch Lucinda Williams Play A Tiny Desk From Home","videoPrerollAdUrl":"https:\/\/pubads.g.doubleclick.net\/gampad\/ads?env=vp&gdfp_req=1&impl=s&unviewed_position_start=1&output=vast&iu=%2F6735%2Fn6735.NPR.MUSIC%2FMusic_Music_Videos&sz=400x300&correlator=1147667762&cust_params=testserver%3Dfalse%26isPodcastEpisode%3Dfalse%26storyId%3D894685942%26agg%3D820178308%2C92071 ...
#    </div>
#
# <!-- END ID='JWPLAYERLIST656281336' DATA-PLAYLIST-ID='JWPLAYLIST656281336' DATA-PLAYER-ID='PLAYER-SHELF656281336' -->
#
#
#         <div class="story-wrap">
#
#
#
#             <div class="story-text-wrap">
#                 <div class="story-text">
#                         <div class="slug-wrap">
#
#                                 <h2 class="slug">
#                                     <a href="https://www.npr.org/sections/music-videos/" data-metrics='{"action":"Click Slug"}'>
#                                     Music Videos
#                                     </a>
#                                 </h2>
#                         </div>
#                     <a href="https://www.npr.org/series/656281336/music-homepage-video-playlist" data-metrics='{"action" : "Click Story 23"}'>
#                         <h3 class="title">carousel tiny desk</h3>
#                     </a>
#
#
#                     <a href="https://www.npr.org/series/656281336/music-homepage-video-playlist" data-metrics='{"action" : "Click Story 23"}'>
#                         <p class="teaser">New and exclusive videos from the popular concert series.</p>
#                     </a>
#                 </div> <!-- /.story-text -->
#
#             </div> <!-- /.story-text-wrap -->
#         </div> <!-- /.story-wrap -->
#     </div> <!-- /.story-wrap-outer -->
# </article>
#       <div id="hp-more-list">
#                </div>
#
# <!-- END ID="HP-MORE-LIST" -->
#    </div>
#
# <!-- END CLASS="STORIES-WRAP STORIES-WRAP-TWO" DATA-METRICS-CATEGORY="CURATED LIST" -->
#    <div id="hp-more" data-metrics-all>
#             <div class="hp-label">
#          more from
#       </div>
#       <ul>
#                   <li><a href="/sections/news/" class="more-button option" data-metrics-category="Curated List" data-metrics-action="More Stories" data-metrics-label="news"><b>news</b></a></li>
#          <li><a href="/sections/arts/" class="more-button option" data-metrics-category="Curated List" data-metrics-action="More Stories" data-metrics-label="arts & life"><b>arts & life</b></a></li>
#          <li><a href="/music/" class="more-button option" data-metrics-category="Curated List" data-metrics-action="More Stories" data-metrics-label="music"><b>music</b></a></li>
#       </ul>
#       <div class='hp-item more-card'>
#                </div>
#    </div>
#
# <!-- END ID="HP-MORE" DATA-METRICS-ALL -->
# </div>
#
# <!-- END ID="CONTENTWRAP" -->
# <footer id="npr-footer" class="npr-footer" role="contentinfo" aria-label="NPR footer"><div class="npr-footer__content" data-metrics-category="Global Footer" data-metrics-label="Footer">
#     <div class="npr-footer__module-group">
#         <div class="npr-footer__module">
#             <h6 class="npr-footer__header">Read &amp; Listen</h6>
#
#             <ul>
#                 <li class="npr-footer__item"><a href="/" data-metrics-action="Click Homepage">Home</a></li>
#                 <li class="npr-footer__item"><a href="/sections/news/" data-metrics-action="Click News">News</a></li>
#                 <li class="npr-footer__item"><a href="/sections/arts/" data-metrics-action="Click Arts &amp; Life">Arts &amp; Life</a></li>
#                 <li class="npr-footer__item"><a href="/music/" data-metrics-action="Click Music">Music</a></li>
#                 <li class="npr-footer__item"><a href="/podcasts/" data-metrics-action="Click Podcasts">Podcasts</a></li>
#                 <li class="npr-footer__item"><a href="/programs/" data-metrics-action="Click Programs">Programs</a></li>
#             </ul>
#         </div>
#
#         <div class="npr-footer__module">
#             <h6 class="npr-footer__header">Connect</h6>
#
#             <ul>
#                 <li class="npr-footer__item"><a href="/newsletters/" data-metrics-action="Click Newsletters">Newsletters</a></li>
#                 <li class="npr-footer__item"><a href="https://www.facebook.com/NPR/" data-metrics-action="Click Facebook">Facebook</a></li>
#                 <li class="npr-footer__item"><a href="https://twitter.com/NPR" data-metrics-action="Click Twitter">Twitter</a></li>
#                 <li class="npr-footer__item"><a href="https://www.instagram.com/npr/" data-metrics-action="Click Instagram">Instagram</a></li>
#                 <li class="npr-footer__item"><a href="https://www.npr.org/contact" data-metrics-action="Click Contact">Contact</a></li>
#                 <li class="npr-footer__item"><a href="https://help.npr.org" data-metrics-action="Click Help">Help</a></li>
#             </ul>
#         </div>
#
#         <div class="npr-footer__module">
#             <h6 class="npr-footer__header">About NPR</h6>
#
#             <ul>
#                 <li class="npr-footer__item"><a href="/about/" data-metrics-action="Click Overview">Overview</a></li>
#                 <li class="npr-footer__item"><a href="/about-npr/178660742/public-radio-finances" data-metrics-action="Click Finances">Finances</a></li>
#                 <li class="npr-footer__item"><a href="/about-npr/179803822/people-at-npr" data-metrics-action="Click People">People</a></li>
#                 <li class="npr-footer__item"><a href="/press/" data-metrics-action="Click Press">Press</a></li>
#                 <li class="npr-footer__item"><a href="/sections/publiceditor/" data-metrics-action="Click Public Editor">Public Editor</a></li>
#                 <li class="npr-footer__item"><a href="/corrections/" data-metrics-action="Click Corrections">Corrections</a></li>
#             </ul>
#         </div>
#
#         <div class="npr-footer__module">
#             <h6 class="npr-footer__header">Get Involved</h6>
#
#             <ul>
#                 <li class="npr-footer__item"><a href="/support/" data-metrics-action="Click Support Public Radio">Support Public Radio</a></li>
#                 <li class="npr-footer__item"><a href="/about-npr/186948703/corporate-sponsorship" data-metrics-action="Click Sponsor NPR">Sponsor NPR</a></li>
#                 <li class="npr-footer__item"><a href="/careers/" data-metrics-action="Click NPR Careers">NPR Careers</a></li>
#                 <li class="npr-footer__item"><a href="https://shop.npr.org/" data-metrics-action="Click NPR Shop">NPR Shop</a></li>
#                 <li class="npr-footer__item"><a href="https://www.nprpresents.org" data-metrics-action="Click NPR Events">NPR Events</a></li>
#                 <li class="npr-footer__item"><a href="/about-npr/177066727/visit-npr" data-metrics-action="Click Visit NPR">Visit NPR</a></li>
#             </ul>
#         </div>
#     </div>
#
#     <div class="npr-footer__module npr-footer__module--secondary">
#         <ul>
#             <li class="npr-footer__item"><a href="/about-npr/179876898/terms-of-use" data-metrics-action="Click Terms of Use">Terms of Use</a></li>
#             <li class="npr-footer__item"><a href="/about-npr/179878450/privacy-policy" data-metrics-action="Click Privacy">Privacy</a></li>
#             <li class="npr-footer__item"><a href="/about-npr/179878450/privacy-policy#yourchoices" data-metrics-action="Click Your Privacy Choices">Your Privacy Choices</a></li>
#             <li class="npr-footer__item"><a href="https://text.npr.org/" data-metrics-action="Click Text Only">Text Only</a></li>
#             <li class="npr-footer__item"><span class="copy-year"></span></li>
#         </ul>
#     </div>
# </div></footer><div id="global-stickybar-mount" class="global-stickybar-mount">
#    </div>
# </section>   <div id="main-sidebar">
#             <aside id="ad-standard-wrap" aria-label="advertisement">
#
#
#     <div id="ad-standard-homepage" class="ad-standard" data-ad-config='{"network":"\/6735\/","site":{"default":"n6735.NPR","mobile":"n6735.NPRMOBILE"},"zone":"homepage","targets":{"testserver":"false","isPodcastEpisode":"false","storyId":"1002"},"location":"standard","deferred":false,"isBetweenContent":false,"isAggSponsorship":false,"borderClass":""}'></div>
#     <p class="left">NPR thanks our sponsors</p><p class="right"><a href="/about-npr/186948703/corporate-sponsorship">Become an NPR sponsor</a></p>
#
# </aside>
#    </div>
#
# <!-- END ID="MAIN-SIDEBAR" -->
# </div>
#
# <!-- END ID="WRAPPER" -->
# <section id="global-modal-mount"></section>
# <!-- END ID="GLOBAL-MODAL-MOUNT" -->
# <script type="text/javascript">
#    (function () {
#     var loadPageJs = function () { webpackJsonp([74,24],{0:function(n,t,c){n.exports=c(1913)},1913:function(n,t,c){"use strict";c.p=NPR.serverVars.webpackPublicPath,function(){var n=2,t=function(){--n<1&&function(n){c(42),c(2289),c(2290),c(257),c(404),c(375),c(826),c(589),c(260)}(c)}.bind(this);c.e(0,t),c.e(13,t)}.call(this)}}); };
#     if (document.readyState === 'complete') {
#         loadPageJs();
#     } else {
#         window.addEventListener('load', function load() {
#             window.removeEventListener('load', load, false);
#             loadPageJs();
#         });
#     }
# })();
# </script>
# </main><noscript><iframe><img height="1" width="1" style="display:none" src="https://www.facebook.com/tr?id=1621557368158968&ev=PageView&noscript=1" /></iframe></noscript><script type='text/javascript'>
#     var _sf_async_config = _sf_async_config || {};
#     /** CONFIGURATION START **/
#     _sf_async_config.uid = '18888';
#     _sf_async_config.domain = NPR.ServerConstants.cbHost;
#     _sf_async_config.useCanonical = true;
#
#     /** CONFIGURATION END **/
#     (function() {
#         function loadChartbeat() {
#             // Wait until the metric for chartbeat have been setup
#             // in templates/javascript/metrics/chartbeat.js
#             if( !!NPR.ChartbeatLoaded) {
#                 var e = document.createElement('script');
#                 e.setAttribute('language', 'javascript');
#                 e.setAttribute('type', 'text/javascript');
#                 e.setAttribute('src', 'https://static.chartbeat.com/js/chartbeat.js');
#                 document.body.appendChild(e);
#             } else {
#                 setTimeout(loadChartbeat, 1000);
#             }
#         }
#
#         var oldonload = window.onload;
#         window.onload = (typeof window.onload != 'function') ?
#                 loadChartbeat : function() {
#             oldonload();
#             window._sf_endpt = (new Date()).getTime();
#             loadChartbeat();
#         };
#     })();
# </script></body></html>

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(res.text, 'html.parser')
# Out:
# ['https://media.npr.org/chrome_svg/npr-logo.svg',
#  'https://media.npr.org/chrome_svg/npr-logo.svg',
#  'https://media.npr.org/chrome_svg/npr-logo.svg',
#  'https://media.npr.org/chrome_svg/npr-logo.svg',
#  'https://media.npr.org/chrome_svg/npr-logo.svg',
#  'https://media.npr.org/chrome_svg/npr-logo.svg',
#  'https://media.npr.org/chrome_svg/npr-logo.svg',
#  'https://media.npr.org/chrome_svg/npr-logo.svg',
#  'https://media.npr.org/chrome_svg/npr-logo.svg',
#  'https://media.npr.org/chrome_svg/npr-logo.svg',
#  'https://media.npr.org/chrome_svg/npr-logo.svg',
#  'https://media.npr.org/chrome_svg/npr-logo.svg',
#  'https://media.npr.org/chrome_svg/npr-logo.svg',
#  'https://media.npr.org/chrome_svg/npr-logo.svg',
#  'https://media.npr.org/chrome_svg/npr-logo.svg',
#  'https://media.npr.org/chrome_svg/npr-logo.svg',
#  'https://media.npr.org/chrome_svg/npr-logo.svg',
#  'https://media.npr.org/chrome_svg/npr-logo.svg',
#  'https://media.npr.org/chrome_svg/npr-logo.svg',
#  'https://media.npr.org/chrome_svg/npr-logo.svg',
#  'https://media.npr.org/chrome_svg/npr-logo.svg',
#  'https://media.npr.org/chrome_svg/npr-logo.svg',
#  'https://media.npr.org/chrome_svg/npr-logo.svg',
#  'https://media.npr.org/chrome_svg/npr-logo.svg',
#  'https://media.npr.org/chrome_svg/npr-logo.svg',
#  'https://media.npr.org/chrome_svg/npr-logo.svg',
#  'https://media.npr.org/chrome_svg/npr-logo.svg',
#  'https://media.npr.org/chrome_svg/npr-logo.svg',
#  'https://media.npr.org/chrome_svg/npr-logo.svg',
#  'https://media.npr.org/chrome_svg/npr-logo.svg',
#  'https://media.npr.org/chrome_svg/npr-logo.svg',
#  'https://media.npr.org/chrome_svg/npr-logo.svg',
#  'https://media.npr.org/chrome_svg/npr-logo.svg',
#  'https://media.npr.org/chrome_svg/npr-logo.svg',
#  'https://media.npr.org/chrome_svg/npr-logo.svg',
#  'https://media.npr.org/chrome_svg/npr-logo.svg',
#  'https://media.npr.org/chrome_svg/npr-logo.svg',
#  'https://media.npr.org/chrome_svg/npr-logo.svg',
#  'https://media.npr.org/chrome_svg/npr-logo.svg',
#  'https://media.npr.org/chrome_svg/npr-logo.svg',
#  'https://media.npr.org/chrome_svg/npr-logo.svg',
#  'https://media.npr.org/chrome_svg/npr-logo.svg',
#  'https://media.npr.org/chrome_svg/npr-logo.svg',
#  'https://media.npr.org/chrome_svg/npr-logo.svg',
#  'https://media.npr.org/chrome_svg/npr-logo.svg',
#  'https://media.npr.org/chrome_svg/npr-logo.svg']

# %%
images = soup.find_all('img')
img_links = [img['src'] for img in images]
img_links
# Out:
# ['https://media.npr.org/chrome_svg/npr-logo.svg',
#  'https://media.npr.org/chrome/programs/logos/morning-edition.jpg',
#  'https://media.npr.org/assets/img/2019/02/26/we_otherentitiestemplatesat_sq-cbde87a2fa31b01047441e6f34d2769b0287bcd4-s100-c85.png',
#  'https://media.npr.org/assets/img/2019/02/26/we_otherentitiestemplatesun_sq-4a03b35e7e5adfa446aec374523a578d54dc9bf5-s100-c85.png',
#  'https://media.npr.org/chrome/programs/logos/all-things-considered.png',
#  'https://media.npr.org/chrome/programs/logos/fresh-air.png',
#  'https://media.npr.org/chrome/programs/logos/up-first.jpg?version=2',
#  'https://media.npr.org/assets/img/2020/05/29/ibam_arttile_final_sq-b6691366c421f19f130bd0beef01c1597c57bdf3.png?s=100',
#  'https://media.npr.org/assets/img/2020/03/24/undefined_sq-63f9f4b46bb9031d67f9785b66818f4befbab8bc.jpg?s=100',
#  'https://media.npr.org/assets/img/2019/01/28/nprthroughline_podcasttile_sq-3bddbe49827adf54bdbc1f94b40fc61d581704f6.png?s=100',
#  'https://media.npr.org/assets/img/2020/06/28/consider-this_podcast-tile_sq-ad4dd62fac1bc1f945b03fcaff3c129fc8b4d640.png?s=100',
#  'https://media.npr.org/chrome_svg/music-logo-dark.svg',
#  'https://media.npr.org/chrome_svg/music-logo-light.svg',
#  'https://media.npr.org/assets/img/2020/08/01/ap_20210746068616_wide-a72c5095d2b9a8debe3475b077996387d3656868-s400-c15.jpg',
#  'https://media.npr.org/assets/img/2020/07/31/mh-img_0531_wide-23fb7c2816775ba86bab7182e9f84b97c44d912b-s400-c15.jpg',
#  'https://media.npr.org/assets/img/2020/07/31/isaias-cone-uncertainty_wide-38fe1696330c4323c128ad52d638ccf4c519221e-s400-c15.png',
#  'https://media.npr.org/assets/img/2020/07/31/gettyimages-1221110459_wide-3055a6cd8ae5aa830c8e32de3167a0860905ee60-s400-c15.jpg',
#  'https://media.npr.org/assets/img/2020/08/01/gettyimages-1224644759_wide-8b7e402017460c0657864ae3f168cab2841ec5dc-s900-c15.jpg',
#  'https://media.npr.org/assets/img/2020/07/31/ap_20213664206566_wide-9651391699a24c9d62a0bff43cc4ea7e01eb97ea-s400-c15.jpg',
#  'https://media.npr.org/assets/img/2020/07/31/gettyimages-1227274700_wide-25614a9a77e6c5d40ace0107c1e8157d6553518f-s400-c15.jpg',
#  'https://media.npr.org/assets/img/2020/07/31/ap_20184602125188_wide-e1c0367362f62ac9d126148f5f1cad1165fbccd2-s400-c15.jpg',
#  'https://media.npr.org/assets/img/2020/08/01/rashidi-noah2_wide-63f4e94a62eb4d896f354466f4d2fdb4558064a0-s900-c15.png',
#  'https://media.npr.org/assets/img/2020/08/01/aurora_powerhouse_forest_wide-cad51ce2e1cebcce7260e9b4ea6cf9a9abcf7215-s400-c15.jpg',
#  'https://media.npr.org/assets/img/2020/08/01/5161-dknxpl_wide-d6aecd9cc54e572109a207c8f79c1740ca59cac1-s400-c15.jpg',
#  'https://media.npr.org/assets/img/2020/07/31/james-murdoch_wide-79385e5ca859e9500ca4632fe4b8812764a324e5-s400-c15.jpg',
#  'https://media.npr.org/assets/img/2020/07/31/gettyimages-1154893930_wide-7cbe4ec91ab80fcf01dbecec43b6f18caac683dd-s900-c15.jpg',
#  'https://media.npr.org/assets/img/2020/07/31/ap_20213596285837_wide-075a918d08d5b087d233e2625d8aa8d9c64b6c33-s400-c15.jpg',
#  'https://media.npr.org/assets/img/2020/07/31/gettyimages-1191955995_wide-5780a5c6fb9e40dc2933712e38aeb3909e1eccc1-s400-c15.jpg',
#  'https://media.npr.org/assets/img/2020/07/31/reneebach18-40_wide-b57dd4e4dd616aa031124fa2567b3384d25adf0b-s400-c15.jpg',
#  'https://media.npr.org/assets/img/2020/07/31/gettyimages-1219954375_wide-866a7105f342c6b5e28a68be7a33cf6042ae9ffe-s900-c15.jpg',
#  'https://media.npr.org/assets/img/2020/07/31/screen-shot-2020-07-31-at-4.05.21-pm-50_wide-26f1b8847f14495694beb5fa63ed24c6ca10b1e1-s400-c15.jpg',
#  'https://media.npr.org/assets/img/2020/07/31/ap_20210680804046_wide-d77cd82ca9720aa6e100407641f289c30d95a3d1-s400-c15.jpg',
#  'https://media.npr.org/assets/img/2020/07/31/dm2_crew_cassidy_iss_wide-566910b4fa41a32e2c1ad97b81167a822c8d2134-s900-c15.jpg',
#  'https://media.npr.org/assets/img/2020/07/31/2020-2.-photo-credit---matthew-reeve_wide-5446d0dd201bf6851445484dbbdc34467c87ad08-s400-c15.jpg',
#  'https://media.npr.org/assets/img/2020/07/31/seamus-coronavirus-d3-us-map-20200312_wide-9ec377cf65a806705337050b63843ea8a7848535-s900-c15.png',
#  'https://media.npr.org/assets/img/2020/07/28/lyric-copy_wide-5f9bc7d9e88451bf6c3547e75b59467de4434cfe-s800-c85.jpg',
#  'https://media.npr.org/assets/img/2020/07/27/thaonguyen_tdhc_thumb_wide-c9fc6d8cb7fe6eb80a515dfe60b0e141e5e3c919-s800-c85.jpg',
#  'https://media.npr.org/assets/img/2020/07/24/lucinda-copy_wide-e6dea4941ad6862d6b601725d919f2cc21db5bd1-s800-c85.jpg',
#  'https://media.npr.org/assets/img/2020/07/21/thumb_wide-635d26225c2c45bf836e71c10314ffa0fa434f25-s800-c85.jpg',
#  'https://media.npr.org/assets/img/2020/07/20/tomadams_thumb_wide-65e34c9610ad2265652725c971b17a7f8bb6b260-s800-c85.jpg',
#  'https://media.npr.org/assets/img/2020/07/17/lenny-copy_wide-2259465cf70bf1e7131664d0c671dc934ad8c951-s800-c85.jpg',
#  'https://media.npr.org/assets/img/2020/07/15/diananew_wide-40ea6f4ab5aad5b11c8219e932a40f4f0c48f0e1-s800-c85.jpg',
#  'https://media.npr.org/assets/img/2020/07/13/bennysingssocial_wide-9ceb05153744ab1f0b76a3134db3e2ba90f7de31-s800-c85.jpg',
#  'https://media.npr.org/assets/img/2020/07/10/tommischyussefdayes_thumb_wide-b4b249230529d7fd58193e93741e751c3827755c-s800-c85.jpg',
#  'https://media.npr.org/assets/img/2020/07/08/jacob-copy_wide-4b37c9d6b246e79a32d117017340573c0d04e9cb-s800-c85.jpg',
#  'https://www.facebook.com/tr?id=1621557368158968&ev=PageView&noscript=1']

# %%
#from IPython.display import Image
from IPython.core.display import Image, HTML, display

for raw_img in img_links[-15:-5]:
    display(Image(url = raw_img, height=250,width=450))
# Out:
# <img src="https://media.npr.org/assets/img/2020/07/31/ap_20210680804046_wide-d77cd82ca9720aa6e100407641f289c30d95a3d1-s400-c15.jpg" width="450" height="250"/>
# <img src="https://media.npr.org/assets/img/2020/07/31/dm2_crew_cassidy_iss_wide-566910b4fa41a32e2c1ad97b81167a822c8d2134-s900-c15.jpg" width="450" height="250"/>
# <img src="https://media.npr.org/assets/img/2020/07/31/2020-2.-photo-credit---matthew-reeve_wide-5446d0dd201bf6851445484dbbdc34467c87ad08-s400-c15.jpg" width="450" height="250"/>
# <img src="https://media.npr.org/assets/img/2020/07/31/seamus-coronavirus-d3-us-map-20200312_wide-9ec377cf65a806705337050b63843ea8a7848535-s900-c15.png" width="450" height="250"/>
# <img src="https://media.npr.org/assets/img/2020/07/28/lyric-copy_wide-5f9bc7d9e88451bf6c3547e75b59467de4434cfe-s800-c85.jpg" width="450" height="250"/>
# <img src="https://media.npr.org/assets/img/2020/07/27/thaonguyen_tdhc_thumb_wide-c9fc6d8cb7fe6eb80a515dfe60b0e141e5e3c919-s800-c85.jpg" width="450" height="250"/>
# <img src="https://media.npr.org/assets/img/2020/07/24/lucinda-copy_wide-e6dea4941ad6862d6b601725d919f2cc21db5bd1-s800-c85.jpg" width="450" height="250"/>
# <img src="https://media.npr.org/assets/img/2020/07/21/thumb_wide-635d26225c2c45bf836e71c10314ffa0fa434f25-s800-c85.jpg" width="450" height="250"/>
# <img src="https://media.npr.org/assets/img/2020/07/20/tomadams_thumb_wide-65e34c9610ad2265652725c971b17a7f8bb6b260-s800-c85.jpg" width="450" height="250"/>
# <img src="https://media.npr.org/assets/img/2020/07/17/lenny-copy_wide-2259465cf70bf1e7131664d0c671dc934ad8c951-s800-c85.jpg" width="450" height="250"/>
